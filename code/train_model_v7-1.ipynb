# %% [markdown]
# # Imports & Setup

# %% [markdown]
# ## Imports

# %%
# Imports
import numpy as np
import random
import statistics
import copy

from typing import Literal, List

import os

import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

from torchvision.transforms import v2 as T
import torchvision.transforms.functional as F

import torch.optim as optim

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models

from tqdm.notebook import tqdm

# %% [markdown]
# ## Set Seed For Reproducibility

# %%
# Sets random seeds for reproducibility
def set_seed(seed):
    # Set seed for PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        # Set seed for all available GPUs
        torch.cuda.manual_seed_all(seed)

    # Set seed for NumPy
    np.random.seed(seed)

    # Set seed for Python's built-in random module
    random.seed(seed)

    # Enable deterministic algorithms for reproducibility
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Use deterministic algorithms where available
    torch.use_deterministic_algorithms(True)

# Set random seeds
my_seed = 42
set_seed(my_seed)

# %% [markdown]
# ## Files Loading

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Config
# Path to dataset (Each group member may need to modify this)
DATASET_CLEAR_FILEPATH_IN_DRIVE = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/data_clean/data_clean_v2.zip"

# %%
# Copy data clean zip from Google Drive
# !cp "{DATASET_CLEAR_FILEPATH_IN_DRIVE}" "/content/data.zip"

# %%
# Unzip data raw zip
# !unzip "/content/data.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_clean/Test/Fake/fake_1756.jpg
#   inflating: data_clean/Test/Fake/fake_70.jpg
#   inflating: data_clean/Test/Fake/fake_2271.jpg
#   inflating: data_clean/Test/Fake/fake_620.jpg
#   inflating: data_clean/Test/Fake/fake_2610.jpg
#   inflating: data_clean/Test/Fake/fake_4635.jpg
#   inflating: data_clean/Test/Fake/fake_5307.jpg
#   inflating: data_clean/Test/Fake/fake_604.jpg
#   inflating: data_clean/Test/Fake/fake_4021.jpg
#   inflating: data_clean/Test/Fake/fake_5426.jpg
#   inflating: data_clean/Test/Fake/fake_1661.jpg
#   inflating: data_clean/Test/Fake/fake_1202.jpg
#   inflating: data_clean/Test/Fake/fake_2957.jpg
#   inflating: data_clean/Test/Fake/fake_2213.jpg
#   inflating: data_clean/Test/Fake/fake_4946.jpg
#   inflating: data_clean/Test/Fake/fake_1275.jpg
#   inflating: data_clean/Test/Fake/fake_5202.jpg
#   inflating: data_clean/Test/Fake/fake_42.jpg
#   inflating: data_clean/Test/Fake/fake_302.jpg
#   inflating: data_clean/Test/Fake/fake_2558.jpg
#   inflating: data_clean/Test/Fake/fake_4499.jpg
#   inflating: data_clean/Test/Fake/fake_539.jpg
#   inflating: data_clean/Test/Fake/fake_4423.jpg
#   inflating: data_clean/Test/Fake/fake_3369.jpg
#   inflating: data_clean/Test/Fake/fake_4658.jpg
#   inflating: data_clean/Test/Fake/fake_819.jpg
#   inflating: data_clean/Test/Fake/fake_3308.jpg
#   inflating: data_clean/Test/Fake/fake_2446.jpg
#   inflating: data_clean/Test/Fake/fake_829.jpg
#   inflating: data_clean/Test/Fake/fake_1942.jpg
#   inflating: data_clean/Test/Fake/fake_1166.jpg
#   inflating: data_clean/Test/Fake/fake_3295.jpg
#   inflating: data_clean/Test/Fake/fake_1027.jpg
#   inflating: data_clean/Test/Fake/fake_34.jpg
#   inflating: data_clean/Test/Fake/fake_2386.jpg
#   inflating: data_clean/Test/Fake/fake_957.jpg
#   inflating: data_clean/Test/Fake/fake_3680.jpg
#   inflating: data_clean/Test/Fake/fake_2733.jpg
#   inflating: data_clean/Test/Fake/fake_1747.jpg
#   inflating: data_clean/Test/Fake/fake_2674.jpg
#   inflating: data_clean/Test/Fake/fake_3245.jpg
#   inflating: data_clean/Test/Fake/fake_2082.jpg
#   inflating: data_clean/Test/Fake/fake_938.jpg
#   inflating: data_clean/Test/Fake/fake_5168.jpg
#   inflating: data_clean/Test/Fake/fake_2290.jpg
#   inflating: data_clean/Test/Fake/fake_3491.jpg
#   inflating: data_clean/Test/Fake/fake_4707.jpg
#   inflating: data_clean/Test/Fake/fake_4966.jpg
#   inflating: data_clean/Test/Fake/fake_2745.jpg
#   inflating: data_clean/Test/Fake/fake_3863.jpg
#   inflating: data_clean/Test/Fake/fake_5207.jpg
#   inflating: data_clean/Test/Fake/fake_4493.jpg
#   inflating: data_clean/Test/Fake/fake_867.jpg
#   inflating: data_clean/Test/Fake/fake_4007.jpg
#   inflating: data_clean/Test/Fake/fake_2404.jpg
#   inflating: data_clean/Test/Fake/fake_338.jpg
#   inflating: data_clean/Test/Fake/fake_3200.jpg
#   inflating: data_clean/Test/Fake/fake_4905.jpg
#   inflating: data_clean/Test/Fake/fake_3468.jpg
#   inflating: data_clean/Test/Fake/fake_1884.jpg
#   inflating: data_clean/Test/Fake/fake_2714.jpg
#   inflating: data_clean/Test/Fake/fake_3328.jpg
#   inflating: data_clean/Test/Fake/fake_2791.jpg
#   inflating: data_clean/Test/Fake/fake_2224.jpg
#   inflating: data_clean/Test/Fake/fake_1925.jpg
#   inflating: data_clean/Test/Fake/fake_5223.jpg
#   inflating: data_clean/Test/Fake/fake_4575.jpg
#   inflating: data_clean/Test/Fake/fake_3930.jpg
#   inflating: data_clean/Test/Fake/fake_543.jpg
#   inflating: data_clean/Test/Fake/fake_5024.jpg
#   inflating: data_clean/Test/Fake/fake_4660.jpg
#   inflating: data_clean/Test/Fake/fake_2297.jpg
#   inflating: data_clean/Test/Fake/fake_1530.jpg
#   inflating: data_clean/Test/Fake/fake_1028.jpg
#   inflating: data_clean/Test/Fake/fake_4268.jpg
#   inflating: data_clean/Test/Fake/fake_746.jpg
#   inflating: data_clean/Test/Fake/fake_2455.jpg
#   inflating: data_clean/Test/Fake/fake_4859.jpg
#   inflating: data_clean/Test/Fake/fake_2640.jpg
#   inflating: data_clean/Test/Fake/fake_3275.jpg
#   inflating: data_clean/Test/Fake/fake_4272.jpg
#   inflating: data_clean/Test/Fake/fake_2817.jpg
#   inflating: data_clean/Test/Fake/fake_5191.jpg
#   inflating: data_clean/Test/Fake/fake_3878.jpg
#   inflating: data_clean/Test/Fake/fake_535.jpg
#   inflating: data_clean/Test/Fake/fake_871.jpg
#   inflating: data_clean/Test/Fake/fake_1334.jpg
#   inflating: data_clean/Test/Fake/fake_4508.jpg
#   inflating: data_clean/Test/Fake/fake_2967.jpg
#   inflating: data_clean/Test/Fake/fake_3475.jpg
#   inflating: data_clean/Test/Fake/fake_3880.jpg
#   inflating: data_clean/Test/Fake/fake_263.jpg
#   inflating: data_clean/Test/Fake/fake_4193.jpg
#   inflating: data_clean/Test/Fake/fake_3081.jpg
#   inflating: data_clean/Test/Fake/fake_1190.jpg
#   inflating: data_clean/Test/Fake/fake_2926.jpg
#   inflating: data_clean/Test/Fake/fake_3628.jpg
#   inflating: data_clean/Test/Fake/fake_305.jpg
#   inflating: data_clean/Test/Fake/fake_4102.jpg
#   inflating: data_clean/Test/Fake/fake_2443.jpg
#   inflating: data_clean/Test/Fake/fake_442.jpg
#   inflating: data_clean/Test/Fake/fake_1436.jpg
#   inflating: data_clean/Test/Fake/fake_4593.jpg
#   inflating: data_clean/Test/Fake/fake_466.jpg
#   inflating: data_clean/Test/Fake/fake_1119.jpg
#   inflating: data_clean/Test/Fake/fake_1533.jpg
#   inflating: data_clean/Test/Fake/fake_1577.jpg
#   inflating: data_clean/Test/Fake/fake_580.jpg
#   inflating: data_clean/Test/Fake/fake_2650.jpg
#   inflating: data_clean/Test/Fake/fake_4111.jpg
#   inflating: data_clean/Test/Fake/fake_2430.jpg
#   inflating: data_clean/Test/Fake/fake_3755.jpg
#   inflating: data_clean/Test/Fake/fake_5297.jpg
#   inflating: data_clean/Test/Fake/fake_4916.jpg
#   inflating: data_clean/Test/Fake/fake_3987.jpg
#   inflating: data_clean/Test/Fake/fake_2197.jpg
#   inflating: data_clean/Test/Fake/fake_1403.jpg
#   inflating: data_clean/Test/Fake/fake_928.jpg
#   inflating: data_clean/Test/Fake/fake_5342.jpg
#   inflating: data_clean/Test/Fake/fake_2131.jpg
#   inflating: data_clean/Test/Fake/fake_4779.jpg
#   inflating: data_clean/Test/Fake/fake_3129.jpg
#   inflating: data_clean/Test/Fake/fake_2432.jpg
#   inflating: data_clean/Test/Fake/fake_4216.jpg
#   inflating: data_clean/Test/Fake/fake_749.jpg
#   inflating: data_clean/Test/Fake/fake_1643.jpg
#   inflating: data_clean/Test/Fake/fake_1098.jpg
#   inflating: data_clean/Test/Fake/fake_5322.jpg
#   inflating: data_clean/Test/Fake/fake_3797.jpg
#   inflating: data_clean/Test/Fake/fake_240.jpg
#   inflating: data_clean/Test/Fake/fake_4205.jpg
#   inflating: data_clean/Test/Fake/fake_2498.jpg
#   inflating: data_clean/Test/Fake/fake_3975.jpg
#   inflating: data_clean/Test/Fake/fake_4294.jpg
#   inflating: data_clean/Test/Fake/fake_5178.jpg
#   inflating: data_clean/Test/Fake/fake_4824.jpg
#   inflating: data_clean/Test/Fake/fake_1768.jpg
#   inflating: data_clean/Test/Fake/fake_3339.jpg
#   inflating: data_clean/Test/Fake/fake_1818.jpg
#   inflating: data_clean/Test/Fake/fake_4825.jpg
#   inflating: data_clean/Test/Fake/fake_3356.jpg
#   inflating: data_clean/Test/Fake/fake_1962.jpg
#   inflating: data_clean/Test/Fake/fake_3363.jpg
#   inflating: data_clean/Test/Fake/fake_2543.jpg
#   inflating: data_clean/Test/Fake/fake_5040.jpg
#   inflating: data_clean/Test/Fake/fake_3853.jpg
#   inflating: data_clean/Test/Fake/fake_3084.jpg
#   inflating: data_clean/Test/Fake/fake_2412.jpg
#   inflating: data_clean/Test/Fake/fake_1663.jpg
#   inflating: data_clean/Test/Fake/fake_194.jpg
#   inflating: data_clean/Test/Fake/fake_941.jpg
#   inflating: data_clean/Test/Fake/fake_4407.jpg
#   inflating: data_clean/Test/Fake/fake_727.jpg
#   inflating: data_clean/Test/Fake/fake_4704.jpg
#   inflating: data_clean/Test/Fake/fake_2892.jpg
#   inflating: data_clean/Test/Fake/fake_642.jpg
#   inflating: data_clean/Test/Fake/fake_1597.jpg
#   inflating: data_clean/Test/Fake/fake_4088.jpg
#   inflating: data_clean/Test/Fake/fake_4413.jpg
#   inflating: data_clean/Test/Fake/fake_974.jpg
#   inflating: data_clean/Test/Fake/fake_5382.jpg
#   inflating: data_clean/Test/Fake/fake_1990.jpg
#   inflating: data_clean/Test/Fake/fake_785.jpg
#   inflating: data_clean/Test/Fake/fake_3078.jpg
#   inflating: data_clean/Test/Fake/fake_2122.jpg
#   inflating: data_clean/Test/Fake/fake_1337.jpg
#   inflating: data_clean/Test/Fake/fake_4693.jpg
#   inflating: data_clean/Test/Fake/fake_2844.jpg
#   inflating: data_clean/Test/Fake/fake_1977.jpg
#   inflating: data_clean/Test/Fake/fake_4158.jpg
#   inflating: data_clean/Test/Fake/fake_1318.jpg
#   inflating: data_clean/Test/Fake/fake_2501.jpg
#   inflating: data_clean/Test/Fake/fake_260.jpg
#   inflating: data_clean/Test/Fake/fake_4613.jpg
#   inflating: data_clean/Test/Fake/fake_4140.jpg
#   inflating: data_clean/Test/Fake/fake_4846.jpg
#   inflating: data_clean/Test/Fake/fake_3623.jpg
#   inflating: data_clean/Test/Fake/fake_2675.jpg
#   inflating: data_clean/Test/Fake/fake_1595.jpg
#   inflating: data_clean/Test/Fake/fake_1268.jpg
#   inflating: data_clean/Test/Fake/fake_2187.jpg
#   inflating: data_clean/Test/Fake/fake_4081.jpg
#   inflating: data_clean/Test/Fake/fake_1168.jpg
#   inflating: data_clean/Test/Fake/fake_3246.jpg
#   inflating: data_clean/Test/Fake/fake_4571.jpg
#   inflating: data_clean/Test/Fake/fake_2022.jpg
#   inflating: data_clean/Test/Fake/fake_5030.jpg
#   inflating: data_clean/Test/Fake/fake_1370.jpg
#   inflating: data_clean/Test/Fake/fake_4439.jpg
#   inflating: data_clean/Test/Fake/fake_3255.jpg
#   inflating: data_clean/Test/Fake/fake_2289.jpg
#   inflating: data_clean/Test/Fake/fake_3523.jpg
#   inflating: data_clean/Test/Fake/fake_4666.jpg
#   inflating: data_clean/Test/Fake/fake_2285.jpg
#   inflating: data_clean/Test/Fake/fake_4027.jpg
#   inflating: data_clean/Test/Fake/fake_4261.jpg
#   inflating: data_clean/Test/Fake/fake_5364.jpg
#   inflating: data_clean/Test/Fake/fake_2329.jpg
#   inflating: data_clean/Test/Fake/fake_1430.jpg
#   inflating: data_clean/Test/Fake/fake_1443.jpg
#   inflating: data_clean/Test/Fake/fake_4043.jpg
#   inflating: data_clean/Test/Fake/fake_149.jpg
# ...
#   inflating: data_clean/Test/Real/real_2977.jpg
#   inflating: data_clean/Test/Real/real_4957.jpg
#   inflating: data_clean/Test/Real/real_4085.jpg
#   inflating: data_clean/Test/Real/real_3453.jpg
#   inflating: data_clean/Test/Real/real_2546.jpg
#   inflating: data_clean/Test/Real/real_3062.jpg
#   inflating: data_clean/Test/Real/real_4928.jpg
#   inflating: data_clean/Test/Real/real_4715.jpg
#   inflating: data_clean/Test/Real/real_4397.jpg
#   inflating: data_clean/Test/Real/real_773.jpg
#   inflating: data_clean/Test/Real/real_4615.jpg
#   inflating: data_clean/Test/Real/real_5392.jpg
#   inflating: data_clean/Test/Real/real_1948.jpg
#   inflating: data_clean/Test/Real/real_1916.jpg
#   inflating: data_clean/Test/Real/real_2060.jpg
#   inflating: data_clean/Test/Real/real_4017.jpg
#   inflating: data_clean/Test/Real/real_2161.jpg
#   inflating: data_clean/Test/Real/real_3093.jpg
#   inflating: data_clean/Test/Real/real_796.jpg
#   inflating: data_clean/Test/Real/real_5231.jpg
#   inflating: data_clean/Test/Real/real_3331.jpg
#   inflating: data_clean/Test/Real/real_2093.jpg
#   inflating: data_clean/Test/Real/real_4703.jpg
#   inflating: data_clean/Test/Real/real_2019.jpg
#   inflating: data_clean/Test/Real/real_2333.jpg
#   inflating: data_clean/Test/Real/real_2332.jpg
#   inflating: data_clean/Test/Real/real_2461.jpg
#   inflating: data_clean/Test/Real/real_2226.jpg
#   inflating: data_clean/Test/Real/real_1381.jpg
#   inflating: data_clean/Test/Real/real_3039.jpg
#   inflating: data_clean/Test/Real/real_5380.jpg
#   inflating: data_clean/Test/Real/real_3083.jpg
#   inflating: data_clean/Test/Real/real_5161.jpg
#   inflating: data_clean/Test/Real/real_3792.jpg
#   inflating: data_clean/Test/Real/real_1552.jpg
#   inflating: data_clean/Test/Real/real_278.jpg
#   inflating: data_clean/Test/Real/real_2456.jpg
#   inflating: data_clean/Test/Real/real_3529.jpg
#   inflating: data_clean/Test/Real/real_2330.jpg
#   inflating: data_clean/Test/Real/real_722.jpg
#   inflating: data_clean/Test/Real/real_3653.jpg
#   inflating: data_clean/Test/Real/real_1327.jpg
#   inflating: data_clean/Test/Real/real_1858.jpg
#   inflating: data_clean/Test/Real/real_3245.jpg
#   inflating: data_clean/Test/Real/real_4405.jpg
#   inflating: data_clean/Test/Real/real_2453.jpg
#   inflating: data_clean/Test/Real/real_4090.jpg
#   inflating: data_clean/Test/Real/real_439.jpg
#   inflating: data_clean/Test/Real/real_956.jpg
#   inflating: data_clean/Test/Real/real_1353.jpg
#   inflating: data_clean/Test/Real/real_2391.jpg
#   inflating: data_clean/Test/Real/real_1097.jpg
#   inflating: data_clean/Test/Real/real_3130.jpg
#   inflating: data_clean/Test/Real/real_160.jpg
#   inflating: data_clean/Test/Real/real_106.jpg
#   inflating: data_clean/Test/Real/real_3901.jpg
#   inflating: data_clean/Test/Real/real_493.jpg
#   inflating: data_clean/Test/Real/real_1042.jpg
#   inflating: data_clean/Test/Real/real_72.jpg
#   inflating: data_clean/Test/Real/real_4723.jpg
#   inflating: data_clean/Test/Real/real_109.jpg
#   inflating: data_clean/Test/Real/real_2014.jpg
#   inflating: data_clean/Test/Real/real_1297.jpg
#   inflating: data_clean/Test/Real/real_4738.jpg
#   inflating: data_clean/Test/Real/real_417.jpg
#   inflating: data_clean/Test/Real/real_3801.jpg
#   inflating: data_clean/Test/Real/real_4272.jpg
#   inflating: data_clean/Test/Real/real_1754.jpg
#   inflating: data_clean/Test/Real/real_688.jpg
#   inflating: data_clean/Test/Real/real_454.jpg
#   inflating: data_clean/Test/Real/real_338.jpg
#   inflating: data_clean/Test/Real/real_420.jpg
#   inflating: data_clean/Test/Real/real_3726.jpg
#   inflating: data_clean/Test/Real/real_442.jpg
#   inflating: data_clean/Test/Real/real_625.jpg
#   inflating: data_clean/Test/Real/real_3116.jpg
#   inflating: data_clean/Test/Real/real_3844.jpg
#   inflating: data_clean/Test/Real/real_600.jpg
#   inflating: data_clean/Test/Real/real_1074.jpg
#   inflating: data_clean/Test/Real/real_1185.jpg
#   inflating: data_clean/Test/Real/real_4842.jpg
#   inflating: data_clean/Test/Real/real_1898.jpg
#   inflating: data_clean/Test/Real/real_4044.jpg
#   inflating: data_clean/Test/Real/real_5144.jpg
#   inflating: data_clean/Test/Real/real_663.jpg
#   inflating: data_clean/Test/Real/real_5334.jpg
#   inflating: data_clean/Test/Real/real_705.jpg
#   inflating: data_clean/Test/Real/real_3447.jpg
#   inflating: data_clean/Test/Real/real_5263.jpg
#   inflating: data_clean/Test/Real/real_1957.jpg
#   inflating: data_clean/Test/Real/real_3556.jpg
#   inflating: data_clean/Test/Real/real_885.jpg
#   inflating: data_clean/Test/Real/real_3927.jpg
#   inflating: data_clean/Test/Real/real_1921.jpg
#   inflating: data_clean/Test/Real/real_3379.jpg
#   inflating: data_clean/Test/Real/real_5205.jpg
#   inflating: data_clean/Test/Real/real_4484.jpg
#   inflating: data_clean/Test/Real/real_961.jpg
#   inflating: data_clean/Test/Real/real_2776.jpg
#   inflating: data_clean/Test/Real/real_1226.jpg
#   inflating: data_clean/Test/Real/real_1730.jpg
#   inflating: data_clean/Test/Real/real_3127.jpg
#   inflating: data_clean/Test/Real/real_4661.jpg
#   inflating: data_clean/Test/Real/real_1247.jpg
#   inflating: data_clean/Test/Real/real_3431.jpg
#   inflating: data_clean/Test/Real/real_519.jpg
#   inflating: data_clean/Test/Real/real_5123.jpg
#   inflating: data_clean/Test/Real/real_5271.jpg
#   inflating: data_clean/Test/Real/real_1285.jpg
#   inflating: data_clean/Test/Real/real_4332.jpg
#   inflating: data_clean/Test/Real/real_1595.jpg
#   inflating: data_clean/Test/Real/real_1550.jpg
#   inflating: data_clean/Test/Real/real_49.jpg
#   inflating: data_clean/Test/Real/real_4354.jpg
#   inflating: data_clean/Test/Real/real_2609.jpg
#   inflating: data_clean/Test/Real/real_3843.jpg
#   inflating: data_clean/Test/Real/real_2685.jpg
#   inflating: data_clean/Test/Real/real_3717.jpg
#   inflating: data_clean/Test/Real/real_4728.jpg
#   inflating: data_clean/Test/Real/real_3057.jpg
#   inflating: data_clean/Test/Real/real_401.jpg
#   inflating: data_clean/Test/Real/real_1901.jpg
#   inflating: data_clean/Test/Real/real_5213.jpg
#   inflating: data_clean/Test/Real/real_3205.jpg
#   inflating: data_clean/Test/Real/real_3563.jpg
#   inflating: data_clean/Test/Real/real_3665.jpg
#   inflating: data_clean/Test/Real/real_4105.jpg
#   inflating: data_clean/Test/Real/real_4393.jpg
#   inflating: data_clean/Test/Real/real_3740.jpg
#   inflating: data_clean/Test/Real/real_2201.jpg
#   inflating: data_clean/Test/Real/real_111.jpg
#   inflating: data_clean/Test/Real/real_1261.jpg
#   inflating: data_clean/Test/Real/real_175.jpg
#   inflating: data_clean/Test/Real/real_1618.jpg
#   inflating: data_clean/Test/Real/real_1672.jpg
#   inflating: data_clean/Test/Real/real_1389.jpg
#   inflating: data_clean/Test/Real/real_5239.jpg
#   inflating: data_clean/Test/Real/real_3050.jpg
#   inflating: data_clean/Test/Real/real_5202.jpg
#   inflating: data_clean/Test/Real/real_2721.jpg
#   inflating: data_clean/Test/Real/real_3199.jpg
#   inflating: data_clean/Test/Real/real_1436.jpg
#   inflating: data_clean/Test/Real/real_3654.jpg
#   inflating: data_clean/Test/Real/real_2843.jpg
#   inflating: data_clean/Test/Real/real_802.jpg
#   inflating: data_clean/Test/Real/real_3240.jpg
#   inflating: data_clean/Test/Real/real_3757.jpg
#   inflating: data_clean/Test/Real/real_2159.jpg
#   inflating: data_clean/Test/Real/real_1308.jpg
#   inflating: data_clean/Test/Real/real_1925.jpg
#   inflating: data_clean/Test/Real/real_4100.jpg
#   inflating: data_clean/Test/Real/real_2489.jpg
#   inflating: data_clean/Test/Real/real_1617.jpg
#   inflating: data_clean/Test/Real/real_1556.jpg
#   inflating: data_clean/Test/Real/real_214.jpg
#   inflating: data_clean/Test/Real/real_1225.jpg
#   inflating: data_clean/Test/Real/real_3176.jpg
#   inflating: data_clean/Test/Real/real_628.jpg
#   inflating: data_clean/Test/Real/real_3069.jpg
#   inflating: data_clean/Test/Real/real_2499.jpg
#   inflating: data_clean/Test/Real/real_3912.jpg
#   inflating: data_clean/Test/Real/real_779.jpg
#   inflating: data_clean/Test/Real/real_2128.jpg
#   inflating: data_clean/Test/Real/real_5010.jpg
#   inflating: data_clean/Test/Real/real_16.jpg
#   inflating: data_clean/Test/Real/real_2694.jpg
#   inflating: data_clean/Test/Real/real_3343.jpg
#   inflating: data_clean/Test/Real/real_845.jpg
#   inflating: data_clean/Test/Real/real_5116.jpg
#   inflating: data_clean/Test/Real/real_3195.jpg
#   inflating: data_clean/Test/Real/real_968.jpg
#   inflating: data_clean/Test/Real/real_255.jpg
#   inflating: data_clean/Test/Real/real_4807.jpg
#   inflating: data_clean/Test/Real/real_4593.jpg
#   inflating: data_clean/Test/Real/real_883.jpg
#   inflating: data_clean/Test/Real/real_1371.jpg
#   inflating: data_clean/Test/Real/real_1641.jpg
#   inflating: data_clean/Test/Real/real_3624.jpg
#   inflating: data_clean/Test/Real/real_299.jpg
#   inflating: data_clean/Test/Real/real_3894.jpg
#   inflating: data_clean/Test/Real/real_4149.jpg
#   inflating: data_clean/Test/Real/real_1644.jpg
#   inflating: data_clean/Test/Real/real_4381.jpg
#   inflating: data_clean/Test/Real/real_4234.jpg
#   inflating: data_clean/Test/Real/real_2753.jpg
#   inflating: data_clean/Test/Real/real_1423.jpg
#   inflating: data_clean/Test/Real/real_3483.jpg
#   inflating: data_clean/Test/Real/real_1300.jpg
#   inflating: data_clean/Test/Real/real_3.jpg
#   inflating: data_clean/Test/Real/real_3051.jpg
#   inflating: data_clean/Test/Real/real_2683.jpg
#   inflating: data_clean/Test/Real/real_2953.jpg
#   inflating: data_clean/Test/Real/real_1036.jpg
#   inflating: data_clean/Test/Real/real_833.jpg
#   inflating: data_clean/Test/Real/real_4725.jpg
#   inflating: data_clean/Test/Real/real_4159.jpg
#   inflating: data_clean/Test/Real/real_1797.jpg
#   inflating: data_clean/Test/Real/real_991.jpg
#   inflating: data_clean/Test/Real/real_3452.jpg
#   inflating: data_clean/Test/Real/real_1578.jpg
#   inflating: data_clean/Test/Real/real_1537.jpg
#   inflating: data_clean/Test/Real/real_457.jpg
#   inflating: data_clean/Test/Real/real_60.jpg
#   inflating: data_clean/Test/Real/real_3524.jpg
#   inflating: data_clean/Test/Real/real_3148.jpg
#   inflating: data_clean/Test/Real/real_2091.jpg
#   inflating: data_clean/Test/Real/real_2849.jpg
#   inflating: data_clean/Test/Real/real_4067.jpg
#   inflating: data_clean/Test/Real/real_294.jpg
#   inflating: data_clean/Test/Real/real_2666.jpg
#   inflating: data_clean/Test/Real/real_3207.jpg
#   inflating: data_clean/Test/Real/real_282.jpg
#   inflating: data_clean/Test/Real/real_2527.jpg
#   inflating: data_clean/Test/Real/real_3943.jpg
#   inflating: data_clean/Test/Real/real_2150.jpg
#   inflating: data_clean/Test/Real/real_1431.jpg
#   inflating: data_clean/Test/Real/real_215.jpg
#   inflating: data_clean/Test/Real/real_4806.jpg
#   inflating: data_clean/Test/Real/real_4196.jpg
#   inflating: data_clean/Test/Real/real_1045.jpg
#   inflating: data_clean/Test/Real/real_3209.jpg
#   inflating: data_clean/Test/Real/real_4819.jpg
#   inflating: data_clean/Test/Real/real_2355.jpg
#   inflating: data_clean/Test/Real/real_2190.jpg
#   inflating: data_clean/Test/Real/real_3177.jpg
#   inflating: data_clean/Test/Real/real_1945.jpg
#   inflating: data_clean/Test/Real/real_5185.jpg
#   inflating: data_clean/Test/Real/real_4288.jpg
#   inflating: data_clean/Test/Real/real_202.jpg
#   inflating: data_clean/Test/Real/real_343.jpg
#   inflating: data_clean/Test/Real/real_4243.jpg
#   inflating: data_clean/Test/Real/real_3077.jpg
#   inflating: data_clean/Test/Real/real_5331.jpg
#   inflating: data_clean/Test/Real/real_3080.jpg
#   inflating: data_clean/Test/Real/real_5328.jpg
#   inflating: data_clean/Test/Real/real_2672.jpg
#   inflating: data_clean/Test/Real/real_1772.jpg
#   inflating: data_clean/Test/Real/real_133.jpg
#   inflating: data_clean/Test/Real/real_960.jpg
#   inflating: data_clean/Test/Real/real_1545.jpg
#   inflating: data_clean/Test/Real/real_2698.jpg
#   inflating: data_clean/Test/Real/real_1018.jpg
#   inflating: data_clean/Test/Real/real_895.jpg
#   inflating: data_clean/Test/Real/real_1551.jpg
#   inflating: data_clean/Test/Real/real_3829.jpg
#   inflating: data_clean/Test/Real/real_3600.jpg
#   inflating: data_clean/Test/Real/real_4588.jpg
#   inflating: data_clean/Test/Real/real_1190.jpg
#   inflating: data_clean/Test/Real/real_228.jpg
#   inflating: data_clean/Test/Real/real_3219.jpg
#   inflating: data_clean/Test/Real/real_4073.jpg
#   inflating: data_clean/Test/Real/real_2882.jpg
#   inflating: data_clean/Test/Real/real_3671.jpg
#   inflating: data_clean/Test/Real/real_2384.jpg
#   inflating: data_clean/Test/Real/real_2758.jpg
#   inflating: data_clean/Test/Real/real_1654.jpg
#   inflating: data_clean/Test/Real/real_2441.jpg
#   inflating: data_clean/Test/Real/real_797.jpg
#   inflating: data_clean/Test/Real/real_2757.jpg
#   inflating: data_clean/Test/Real/real_3337.jpg
#   inflating: data_clean/Test/Real/real_667.jpg
#   inflating: data_clean/Test/Real/real_3178.jpg

# %% [markdown]
# ## Setup GPU

# %%
# Set device to GPU if available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # Datasets

# %%
class Dataset(Dataset):
  def __init__(
              self,
              root_dir,
              transform=None,
              split: Literal["train", "val", "test"] = "train",
              ):
    self.transform = transform
    self.split = split

    if self.split == "train":
      self.root_dir = os.path.join(root_dir, "Train")
    if self.split == "val":
      self.root_dir = os.path.join(root_dir, "Validation")
    if self.split == "test":
      self.root_dir = os.path.join(root_dir, "Test")

    self.classes = sorted(os.listdir(self.root_dir))
    self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}

    self.samples = []

    for cls in self.classes:
      cls_dir = os.path.join(self.root_dir, cls)

      for file in os.listdir(cls_dir):
        path = os.path.join(cls_dir, file)
        label = self.class_to_idx[cls]

        self.samples.append({
            "path": path,
            "label": label,
        })

  def __getitem__(self, idx):
    img_path = self.samples[idx]["path"]
    label = self.samples[idx]["label"]

    image = Image.open(img_path).convert("RGB")

    if self.transform:
      image = self.transform(image)

    return image, label

  def __len__(self):
    return len(self.samples)

# %% [markdown]
# # Transforms

# %%
# Find size of largest image
root_dir = "/content/data_clean"

widths = []
heights = []

total_files = 0
for root, dirs, files in os.walk(root_dir):
  total_files += len(files)

with tqdm(total = total_files, desc="Checking sizes") as pbar:
  for root, dirs, files in os.walk(root_dir):
    for f in files:
      with Image.open(os.path.join(root, f)) as img:
        width, height = img.size

        widths.append(width)
        heights.append(height)

      pbar.update(1)

print("Max width:", max(widths))
print("Max height:", max(heights))
print()
print("Min width:", min(widths))
print("Min height:", min(heights))
print()
print("Mean width:", statistics.mean(widths))
print("Mean height:", statistics.mean(heights))
print()
print("Median width:", statistics.median(widths))
print("Median height:", statistics.median(heights))
# Out:
# Checking sizes:   0%|          | 0/137137 [00:00<?, ?it/s]
# Max width: 204
# Max height: 204
#
# Min width: 26
# Min height: 26
#
# Mean width: 122.26022153029453
# Mean height: 122.26019965436024
#
# Median width: 118
# Median height: 118

# %%
sns.histplot(data=widths)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=heights)
# Out:
# <Axes: ylabel='Count'>

# %%
class ResizeAndPad:
    def __init__(self, target_size, fill=0):
        self.target_h, self.target_w = target_size
        self.fill = fill

    def __call__(self, img):
        w, h = img.size  # PIL: (width, height)

        if w > self.target_w:
          img.thumbnail((self.target_w, h))
          w, h = img.size  # PIL: (width, height)
        if h > self.target_h:
          img.thumbnail((w, self.target_h))
          w, h = img.size  # PIL: (width, height)

        pad_h = max(self.target_h - h, 0)
        pad_w = max(self.target_w - w, 0)

        # Split padding evenly (center the image)
        padding = (
            pad_w // 2,                    # left
            pad_h // 2,                    # top
            pad_w - pad_w // 2,            # right
            pad_h - pad_h // 2             # bottom
        )

        return F.pad(img, padding, fill=self.fill)

# %%
img_size = 150

# Base transforms for val, test, and inference
base_transforms = T.Compose([
  ResizeAndPad((img_size, img_size)),

  T.ToImage(),
  T.ToDtype(torch.float32, scale=True),

  T.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
  )
])

# Aug transforms for train
aug_transforms = T.Compose([
  ResizeAndPad((img_size, img_size)),

  T.RandomHorizontalFlip(p=0.5),

  T.ColorJitter(
    brightness=0.2,
    contrast=0.2,
    saturation=0.2
  ),

  T.ToImage(),
  T.ToDtype(torch.float32, scale=True),

  T.Normalize(
      mean=[0.485, 0.456, 0.406],
      std=[0.229, 0.224, 0.225]
  )
])

# %% [markdown]
# # Training Model

# %% [markdown]
# ## Config

# %%
# Config

# Subset
train_on_subset = False
subset_size_proportion = 0.1

# Training
num_epochs = 30
batch_size = 128
num_workers = 2
patience = 5 # Stop if no improvement after
min_delta = 0.0005 # Amt decrease in loss needed for action

# Optimizer
learning_rate = 0.0001
betas = (0.9, 0.990)
weight_decay = 0.0001

# Learning rate scheduler
step_size = 7
gamma = 0.5

# Saves
best_model_filepath = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/best_model"
checkpoint_filepath = "/content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints"

# %% [markdown]
# ## DataLoaders

# %%
# Load datasets for train, val, and test
train_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=aug_transforms,
    split="train",
)

val_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=base_transforms,
    split="val",
)

test_dataset = Dataset(
    root_dir="/content/data_clean/",
    transform=base_transforms,
    split="test",
)

# Print classes
print("Class IDs train:", train_dataset.class_to_idx)
print("Class IDs val:", val_dataset.class_to_idx)
print("Class IDs test:", test_dataset.class_to_idx)

if train_on_subset:
  from torch.utils.data import Subset

  train_n = min(int(len(train_dataset) * subset_size_proportion), len(train_dataset))
  val_n   = min(int(len(val_dataset) * subset_size_proportion), len(val_dataset))
  test_n  = min(int(len(test_dataset) * subset_size_proportion), len(test_dataset))

  train_indices = torch.randperm(len(train_dataset))[:train_n]
  val_indices   = torch.randperm(len(val_dataset))[:val_n]
  test_indices  = torch.randperm(len(test_dataset))[:test_n]

  train_dataset = Subset(train_dataset, train_indices)
  val_dataset   = Subset(val_dataset, val_indices)
  test_dataset  = Subset(test_dataset, test_indices)

# Print datasets sizes
print("Train dataset size", len(train_dataset))
print("Val dataset size", len(val_dataset))
print("Test dataset size", len(test_dataset))
# Out:
# Class IDs train: {'Fake': 0, 'Real': 1}
# Class IDs val: {'Fake': 0, 'Real': 1}
# Class IDs test: {'Fake': 0, 'Real': 1}
# Train dataset size 101773
# Val dataset size 28141
# Test dataset size 7223

# %%
# Create dataloaders
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=True,
    )

val_datloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
    )

test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
    )

# %% [markdown]
# ## Model

# %%
class DeepFakeDetector(nn.Module):
  def __init__(self):
    super().__init__()

    backbone = models.resnet50(pretrained=False)

    self.features = nn.Sequential(*list(backbone.children())[:-1])

    self.classifier = nn.Sequential(
      nn.Linear(2048, 512),
      nn.ReLU(),
      nn.Dropout(0.2),
      nn.Linear(512, 1)
    )

  def forward(self, x):
    x = self.features(x)
    x = torch.flatten(x, 1)
    x = self.classifier(x)
    return x

# %% [markdown]
# ## Training Setup

# %%
model = DeepFakeDetector()

criterion = nn.BCEWithLogitsLoss()

optimizer = torch.optim.AdamW(
    params=model.parameters(),
    lr=learning_rate,
    betas=betas,
    weight_decay=weight_decay
    )

lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer=optimizer,
    step_size=step_size,
    gamma=gamma
    )
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# ## Training Loop

# %%
# Saves model
def save_model(model, filepath="/content/", model_name="model"):
  torch.save(model.state_dict(), f"{filepath}/{model_name}_state_dict.pth") # Saves state dict
  torch.save(model, f"{filepath}/{model_name}.pth") # Saves entire model
  print("Model saved!")

# %%
def save_checkpoint(epoch, model_state_dict, optimizer_state_dict, loss, results, filepath):
    state = {
        'epoch': epoch,
        'model_state_dict': model_state_dict,
        'optimizer_state_dict': optimizer_state_dict,
        'loss': loss,
        'results': results,
    }
    torch.save(state, filepath)
    print(f"Checkpoint saved to {filepath}")

# %%
def validate(model, dataloader, loss_function, epoch, num_epochs):
  model.eval()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  with torch.no_grad():
    pbar = tqdm(
              dataloader,
              desc=f"Epoch {epoch+1}/{num_epochs} [Validation]",
              leave=True,
              dynamic_ncols=True
              )
    for images, labels in pbar:
      images = images.to(device)
      labels = labels.to(device).float().unsqueeze(1)

      outputs = model(images)
      loss = loss_function(outputs, labels)
      total_loss += loss.item() * len(images)
      pred_labels = (outputs >= 0)
      total_correct += (pred_labels == labels).sum().item()
      total_samples += labels.size(0)

      avg_loss = total_loss / total_samples
      avg_acc = total_correct / total_samples

      pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

  return avg_loss, avg_acc

# %%
def train_one_epoch(model, dataloader, optimizer, loss_function, lr_scheduler, device, epoch, num_epochs):
  model.train()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  pbar = tqdm(
              dataloader,
              desc=f"Epoch {epoch+1}/{num_epochs} [Train]",
              leave=True,
              dynamic_ncols=True
              )
  for images, labels in pbar:
    images = images.to(device)
    labels = labels.to(device).float().unsqueeze(1)

    # Forward pass
    outputs = model(images)
    loss = loss_function(outputs, labels)

    total_loss += loss.item() * len(images)
    pred_labels = (outputs >= 0)
    total_correct += (pred_labels == labels).sum().item()
    total_samples += labels.size(0)

    avg_loss = total_loss / total_samples
    avg_acc = total_correct / total_samples

    pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

    optimizer.zero_grad()

    # Backward pass
    loss.backward()

    optimizer.step()

  lr_scheduler.step()

  return avg_loss, avg_acc

# %%
def test(model, dataloader, loss_function):
  model.eval()

  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  with torch.no_grad():
    pbar = tqdm(
              dataloader,
              desc="[Test]",
              leave=True,
              dynamic_ncols=True
              )
    for images, labels in pbar:
      images = images.to(device)
      labels = labels.to(device).float().unsqueeze(1)

      outputs = model(images)
      loss = loss_function(outputs, labels)
      total_loss += loss.item() * len(images)
      pred_labels = (outputs >= 0)
      total_correct += (pred_labels == labels).sum().item()
      total_samples += labels.size(0)

      avg_loss = total_loss / total_samples
      avg_acc = total_correct / total_samples

      pbar.set_postfix({"loss": f"{avg_loss:.4f}", "acc": f"{avg_acc:.4f}"})

  return avg_loss, avg_acc

# %%
def train(model, train_loader, val_loader, optimizer, loss_function, lr_scheduler, device, num_epochs):
  train_losses = []
  train_accs = []
  val_losses = []
  val_accs = []
  best_val_loss = float("inf")
  last_model_saved_epoch = 0
  epochs_no_improve = 0
  best_model = copy.deepcopy(model)

  model.to(device) # Move model to device

  for epoch in range(num_epochs):
    # ----TRAIN----
    train_loss, train_acc = train_one_epoch(
        model=model,
        dataloader=train_loader,
        optimizer=optimizer,
        loss_function=loss_function,
        lr_scheduler=lr_scheduler,
        device=device,
        epoch=epoch,
        num_epochs=num_epochs,
    )
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # ----VAL----
    val_loss, val_acc = validate(
        model=model,
        dataloader=val_loader,
        loss_function=loss_function,
        epoch=epoch,
        num_epochs=num_epochs)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"Epoch {epoch+1}/{num_epochs} | Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | Val loss: {val_loss:.4f} | Val acc: {val_acc:.4f}")

    save_checkpoint(
        epoch=epoch + 1,
        model_state_dict=model.state_dict(),
        optimizer_state_dict=optimizer.state_dict(),
        loss=val_loss,
        results=val_acc,
        filepath=f"{checkpoint_filepath}/save_checkpoint_{epoch + 1}.pth")

    # Model save if better than before
    if val_loss < best_val_loss - min_delta:
      best_val_loss = val_loss
      epochs_no_improve = 0
      best_model = copy.deepcopy(model)
      save_model(model, filepath=best_model_filepath)
      last_model_saved_epoch = epoch + 1
    else: # Early stopping if no improvements
      epochs_no_improve += 1
      if epochs_no_improve >= patience:
        print(f"Training stopped early at epoch {epoch + 1}")
        break
      else:
        print(f"No improvement, early stopping may happen after {patience - epochs_no_improve} more epochs if no improvements")

  # ----TEST----
  test_loss, test_acc = test(
      model=best_model,
      dataloader=val_loader,
      loss_function=loss_function)
  print(f"Test with best model: Test loss: {test_loss} | Test acc: {test_acc}")

  history = {
      "train_losses": train_losses,
      "train_accs": train_accs,
      "val_losses": val_losses,
      "val_accs": val_accs,
      "last_model_saved_epoch": last_model_saved_epoch,
      "test_loss": test_loss,
      "test_acc": test_acc
  }

  return history

# %% [markdown]
# ## Plotting

# %%
# Plots training and validation losses
def plot_loss(training_losses: List[float], val_losses: List[float], last_model_saved_epoch: int):
  sns.lineplot(x=range(1, len(training_losses) + 1), y=training_losses, label="Training Loss")
  sns.lineplot(x=range(1, len(val_losses) + 1), y=val_losses, label="Validation Loss")

  plt.xticks(range(1, len(val_losses) + 1))
  plt.axvline(x=last_model_saved_epoch, color='r', linestyle='--', label='Last model saved')
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training vs Validation Loss")
  plt.legend()
  plt.show()

# %%
# Plots training and validation accuracy
def plot_acc(training_accs: List[float], val_accs: List[float], last_model_saved_epoch: int):
  sns.lineplot(x=range(1, len(training_accs) + 1), y=training_accs, label="Training Accuracy")
  sns.lineplot(x=range(1, len(val_accs) + 1), y=val_accs, label="Validation Accuracy")

  plt.xticks(range(1, len(val_accs) + 1))
  plt.axvline(x=last_model_saved_epoch, color='r', linestyle='--', label='Last model saved')
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training vs Validation Accuracy")
  plt.legend()
  plt.show()

# %% [markdown]
# ## Run Training & Show Metrics

# %%
history = train(
    model=model,
    train_loader=train_dataloader,
    val_loader=val_datloader,
    optimizer=optimizer,
    loss_function=criterion,
    lr_scheduler=lr_scheduler,
    device=device,
    num_epochs=num_epochs
    )
# Out:
# Epoch 1/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 1/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 1/30 | Train loss: 0.4233 | Train acc: 0.8017 | Val loss: 0.2945 | Val acc: 0.8739
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_1.pth
# Model saved!
# Epoch 2/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 2/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 2/30 | Train loss: 0.2012 | Train acc: 0.9199 | Val loss: 0.4321 | Val acc: 0.8310
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_2.pth
# No improvement, early stopping may happen after 4 more epochs if no improvements
# Epoch 3/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 3/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 3/30 | Train loss: 0.1449 | Train acc: 0.9443 | Val loss: 0.1807 | Val acc: 0.9308
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_3.pth
# Model saved!
# Epoch 4/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 4/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 4/30 | Train loss: 0.1164 | Train acc: 0.9560 | Val loss: 0.2011 | Val acc: 0.9176
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_4.pth
# No improvement, early stopping may happen after 4 more epochs if no improvements
# Epoch 5/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 5/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 5/30 | Train loss: 0.0993 | Train acc: 0.9626 | Val loss: 0.1576 | Val acc: 0.9386
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_5.pth
# Model saved!
# Epoch 6/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 6/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 6/30 | Train loss: 0.0885 | Train acc: 0.9662 | Val loss: 0.1629 | Val acc: 0.9369
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_6.pth
# No improvement, early stopping may happen after 4 more epochs if no improvements
# Epoch 7/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 7/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 7/30 | Train loss: 0.0787 | Train acc: 0.9705 | Val loss: 0.1637 | Val acc: 0.9391
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_7.pth
# No improvement, early stopping may happen after 3 more epochs if no improvements
# Epoch 8/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 8/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 8/30 | Train loss: 0.0583 | Train acc: 0.9783 | Val loss: 0.1341 | Val acc: 0.9522
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_8.pth
# Model saved!
# Epoch 9/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 9/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 9/30 | Train loss: 0.0501 | Train acc: 0.9814 | Val loss: 0.1490 | Val acc: 0.9480
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_9.pth
# No improvement, early stopping may happen after 4 more epochs if no improvements
# Epoch 10/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 10/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 10/30 | Train loss: 0.0437 | Train acc: 0.9837 | Val loss: 0.1217 | Val acc: 0.9584
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_10.pth
# Model saved!
# Epoch 11/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 11/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 11/30 | Train loss: 0.0382 | Train acc: 0.9854 | Val loss: 0.1278 | Val acc: 0.9574
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_11.pth
# No improvement, early stopping may happen after 4 more epochs if no improvements
# Epoch 12/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 12/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 12/30 | Train loss: 0.0335 | Train acc: 0.9871 | Val loss: 0.1296 | Val acc: 0.9585
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_12.pth
# No improvement, early stopping may happen after 3 more epochs if no improvements
# Epoch 13/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 13/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 13/30 | Train loss: 0.0301 | Train acc: 0.9886 | Val loss: 0.1360 | Val acc: 0.9601
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_13.pth
# No improvement, early stopping may happen after 2 more epochs if no improvements
# Epoch 14/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 14/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 14/30 | Train loss: 0.0270 | Train acc: 0.9899 | Val loss: 0.1758 | Val acc: 0.9503
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_14.pth
# No improvement, early stopping may happen after 1 more epochs if no improvements
# Epoch 15/30 [Train]:   0%|          | 0/796 [00:00<?, ?it/s]
# Epoch 15/30 [Validation]:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 15/30 | Train loss: 0.0170 | Train acc: 0.9941 | Val loss: 0.1537 | Val acc: 0.9616
# Checkpoint saved to /content/drive/MyDrive/COMP-SCI 5530 - Principles of Data Science/Project/training/training_checkpoints/save_checkpoint_15.pth
# Training stopped early at epoch 15
# [Test]:   0%|          | 0/220 [00:00<?, ?it/s]
# Test with best model: Test loss: 0.12170257856517681 | Test acc: 0.958388116982339

# %%
plot_loss(training_losses=history["train_losses"], val_losses=history["val_losses"], last_model_saved_epoch=history['last_model_saved_epoch'])

# %%
plot_acc(training_accs=history["train_accs"], val_accs=history["val_accs"], last_model_saved_epoch=history['last_model_saved_epoch'])

# %%
from google.colab import runtime
runtime.unassign()
